% %%
warning('off','all');
pkg load symbolic

% %% [markdown]
% # Penyelesaian Persamaan Diferensial

% %% [markdown]
% MATLAB PDE Solver dan ODE Solver dapat digunakan untuk menyelesaikan (sistem) persamaan diferensial baik dalam bentuk PDE maupun ODE. Tentu, tidak semuanya dapat diselesaikan secara simbolik, karena itu ada baiknya untuk mengecek dokumentasi pada MATLAB tentang jenis solver yang bagus untuk menyelesaikan problem yang anda hadapi. Kali ini, kita akan menggunakan `dsolve` untuk menyelesaikan secara simbolik ODE $$y'(t) = \frac{1}{2} (y(t)-t)$$
%
% pada interval $0 \leq t \leq 4$ dan nilai awal $y(0)=1$.

% %%
% Definisikan fungsi simbolik
syms y(t);

% IVP
cond = y(0) == 1;
ode = diff(y, t) == (y-t)/2
% Out:
% ode = (sym)
%
%   d            t   y(t)
%   ──(y(t)) = - ─ + ────
%   dt           2    2

% %% [markdown]
% Selanjutnya, untuk mencari solusi analitik dan plot fungsi pada interval $[0, 4]$ kita lakukan

% %%
ySol(t) = dsolve(ode, cond)

x = linspace(0, 4);
ysol = ySol(x);
ysol = double(rhs(ysol));   % mungkin tidak diperlukan di MATLAB
plot(x, ysol)
% Out:
% ySol(t) = (symfun)
%
%          ⎛         -t     ⎞  t
%          ⎜         ───    ⎟  ─
%          ⎜          2     ⎟  2
%   y(t) = ⎝(t + 2)⋅ℯ    - 1⎠⋅ℯ
%
% Waiting.....

% %% [markdown]
% ## Masalah Nilai Awal (Initial Value Problem)

% %% [markdown]
% Tidak semua permasalahan dapat diselesaikan secara analitik, atau setidaknya secara simbolik menggunakan program komputer. Kali ini, kita akan menggunakan beberapa metode numerik untuk menyelesaikan IVP di awal. Untuk itu, kita akan menggunakan beberapa variabel dibawah ini dalam kode-kode kita selanjutnya.

% %%
% Inisialisasi
a = 0;
b = 4;
h = 0.2;
interval = ceil((b-a)/h);

f = @(t, y) (y-t)/2;   % y' = f(t, y) = (t-y)/2

% %% [markdown]
% ### Single-Step Method

% %% [markdown]
% #### Euler

% %%
% IVP
t = a;
y = zeros(1, interval+1);
y(1) = 1;

% Algoritma
for i = 1:interval
    t = t + h;
    y(i+1) = y(i) + h * f(t, y(i));
end

% %%
plot(x, ysol)
hold on
plot(a:h:b, y)
legend('Analitik', 'Euler')

% %% [markdown]
% #### Heun

% %%
% IVP
t = a;
y = zeros(1, interval+1);
y(1) = 1;

% Algoritma
for i = 1:interval
    P = y(i) + h * f(t, y(i));
    t = t+h;
    y(i+1) = y(i) + h/2 * (f(t-h, y(i)) + f(t, P));
end

% %%
plot(x, ysol)
hold on
plot(a:h:b, y)
legend('Analitik', 'Heun')

% %% [markdown]
% #### Taylor

% %% [markdown]
% #### Runge-Kutta Orde 2

% %%
% IVP
t = a;
y = zeros(1, interval+1);
y(1) = 1;

% Algoritma
for i = 1:interval
    K1 = h * f(t  , y(i));
    K2 = h * f(t+h, y(i) + K1);

    y(i+1) = y(i) + (K1 + K2)/2;
    t = t + h;
end

% %%
plot(x, ysol)
hold on
plot(a:h:b, y)
legend('Analitik', 'RK2')

% %% [markdown]
% #### Runge-Kutta Orde 4

% %%
% IVP
t = a;
y = zeros(1, interval+1);
y(1) = 1;

% Algoritma
for i = 1:interval
    K1 = h * f(t    , y(i)       );
    K2 = h * f(t+h/2, y(i) + K1/2);
    K3 = h * f(t+h/2, y(i) + K2/2);
    K4 = h * f(t+h  , y(i) + K3  );    

    y(i+1) = y(i) + (K1 + 2*K2 + 2*K3 + K4)/6;
    t = t + h;
end

% %%
plot(x, ysol)
hold on
plot(a:h:b, y)
legend('Analitik', 'RK4')

% %% [markdown]
% ### Predictor-Corrector Method

% %% [markdown]
% #### Adam-Bashfort-Moulton

% %%
% IVP
t = a;
y = zeros(1, interval+1);
y(1) = 1;

% Teknik untuk inisialisasi: Heun
for i = 1:3
    Z = y(i) + h * f(t, y(i));
    t = t+h;
    y(i+1) = y(i) + h/2 * (f(t-h, y(i)) + f(t, Z));
end

% Algoritma
for i = 4:interval
    P = y(i) + h/24 * (-  9*f(t-3*h, y(i-3)) ...
                       + 37*f(t-2*h, y(i-2)) ...
                       - 59*f(t  -h, y(i-1)) ...
                       + 55*f(t    , y(i  ))  );

    y(i+1) = y(i) + h/24 * (     f(t-2*h, y(i-2)) ...
                            -  5*f(t-  h, y(i-1)) ...
                            + 19*f(t    , y(i  )) ...
                            +  9*f(t+  h, P     )  );


    t = t+h;
end

% %%
plot(x, ysol)
hold on
plot(a:h:b, y)
legend('Analitik', 'ABM')

% %% [markdown]
% #### Milne-Simpson

% %%
% IVP
t = a;
y = zeros(1, interval+1);
y(1) = 1;

% Teknik untuk inisialisasi: Heun
for i = 1:3
    Z = y(i) + h * f(t, y(i));
    t = t+h;
    y(i+1) = y(i) + h/2 * (f(t-h, y(i)) + f(t, Z));
end


% Algoritma
for i = 4:interval
    P = y(i-3) + 4*h/3 * (  2*f(t-2*h, y(i-2)) ...
                          -   f(t-  h, y(i-1)) ...
                          + 2*f(t    , y(i  ))  );

    y(i+1) = y(i-1) + h/3 * (    f(t-  h, y(i-1)) ...
                             + 4*f(t    , y(i  )) ...
                             +   f(t+  h, P     )  );

    t = t+h;
end

% %%
plot(x, ysol)
hold on
plot(a:h:b, y)
legend('Analitik', 'MS')

% %% [markdown]
% #### Hamming

% %%
% IVP
t = a;
y = zeros(1, interval+1);
y(1) = 1;

% Teknik untuk inisialisasi: Heun
for i = 1:3
    Z = y(i) + h * f(t, y(i));
    t = t+h;
    y(i+1) = y(i) + h/2 * (f(t-h, y(i)) + f(t, Z));
end


% Algoritma
for i = 4:interval
    P = y(i-3) + 4*h/3 * (  2*f(t-2*h, y(i-2)) ...
                          -   f(t-  h, y(i-1)) ...
                          + 2*f(t    , y(i  ))  );

    y(i+1) = (-y(i-2) + 9*y(i))/8 + 3*h/8 * (-   f(t-  h, y(i-1)) ...
                                             + 2*f(t    , y(i  )) ...
                                             +   f(t+  h, P     )  );

    t = t+h;
end

% %%
plot(x, ysol)
hold on
plot(a:h:b, y)
legend('Analitik', 'Hamming')

% %% [markdown]
% ### Sistem Persamaan Diferensial

% %%
f = @(t, x, y) (t - x)/y;
g = @(t, x, y) (t - y)/x;

% %% [markdown]
% #### Euler

% %%
% IVP
t = a;
y = zeros(1, interval+1);
x(1) = 1;
y(1) = 1;

% Algoritma
for i = 1:interval
    t = t + h;
    x(i+1) = x(i) + h * f(t, x(i), y(i));
    y(i+1) = y(i) + h * g(t, x(i), y(i));
end

% %% [markdown]
% #### Runge Kutta Orde 4

% %%
% IVP
t = a;
y = zeros(1, interval+1);
x(1) = 1;
y(1) = 1;

% Program
for i = 1:interval
    K1 = h * f(t      , x(i)       , y(i)       );
    L1 = h * g(t      , x(i)       , y(i)       );
    
    K2 = h * f(t + h/2, x(i) + K1/2, y(i) + L1/2);
    L2 = h * g(t + h/2, x(i) + K1/2, y(i) + L1/2);
    
    K3 = h * f(t + h/2, x(i) + K2/2, y(i) + L2/2);
    L3 = h * g(t + h/2, x(i) + K2/2, y(i) + L2/2);
    
    K4 = h * f(t + h  , x(i) + K3  , y(i) + L3  );
    L4 = h * g(t + h  , x(i) + K3  , y(i) + L3  );
  
    x(i+1) = x(i) + (K1 + 2*K2 + 2*K3 + K4)/6;
    y(i+1) = y(i) + (L1 + 2*L2 + 2*L3 + L4)/6;
    t = t + h;
end

% %% [markdown]
% ## Boundary Value Problem

% %% [markdown]
% #### Tebakan Linear

% %% [markdown]
% #### Beda Hingga

% %% [markdown]
% Misalkan kita memiliki BVP $$x'' + p(t)x' + q(t)x = f(t)$$ di $a\leq t \leq b$ dengan fungsi $u$ bergantung pada $t$ dan memenuhi nilai batas $x(a) = \alpha$ dan $x(b) = \beta$
%
% Dengan menggunakan rumus beda pusat, kita dapat menghampiri diferensial dari fungsi $x(t)$, yakni
% $$x'(t) = \frac{1}{2h} \Big( x(t_{j+1} - x(t_{j-1}) \Big) + O(h^2)$$
% dan
% $$x''(t) = \frac{1}{h^2} \Big( x(t_{j+1} - 2x(t_{j}) + x(t_{j-1}) \Big) + O(h^2)$$
%
% Menyubstitusi hampiran ini ke solusi diferensial awal, menggunakan $p_j = p(t_j)$, $q_j = q(t_j)$, $f_j = f(t_j)$, dan menyusunnya ke dalam bentuk matriks (tridiagonal), kita dapatkan
%
% $$
% \begin{bmatrix}
% 2 + h^2q_1 && \frac{2}{h}p_1 − 1 \\
% -\frac{2}{h}p_1 − 1 && 2 + h^2q_2 && \frac{2}{h}p_2 − 1\\
% && \ddots && \ddots && \ddots &&\\
% && && -\frac{2}{h}p_{n-2} − 1 && 2 + h^2q_{n-2} && \frac{2}{h}p_{n-2} − 1\\
% && && && -\frac{2}{h}p_{n-1} − 1 && 2 + h^2q_{n-1}\\
% \end{bmatrix}
% \begin{bmatrix}
% x_1 \\
% x_2 \\
% \vdots \\
% x_{n-2} \\
% x_{n-1} \\
% \end{bmatrix}
% = h^2
% \begin{bmatrix}
% f_1 \\
% f_2 \\
% \vdots \\
% f_{n-2} \\
% f_{n-1} \\
% \end{bmatrix}
% -
% \begin{bmatrix}
% \alpha \Big( \frac{h}{2}p_1 + 1 \Big) \\
% 0 \\
% \vdots \\
% 0 \\
% \beta \Big( \frac{h}{2}p_{n-1} - 1 \Big) \\
% \end{bmatrix}
% $$
%
% Hal ini dapat diselesaikan dengan menggunakan teknik modifikasi eliminasi Gauss untuk sistem tridiagonal

% %% [markdown]
% ## Bacaan Lain

% %% [markdown]
% * [Numerical Methods for Differential](http://faculty.olin.edu/bstorey/Notes/DiffEq.pdf)
% * [Numerical Methods for Two–Point Boundary Value
% Problems](https://pdfs.semanticscholar.org/74dd/cf24180279a6a78d8ffa95bcbb23567af51a.pdf)
% * [Modules for Numerical Analysis](http://mathfaculty.fullerton.edu/mathews/n2003/NumericalUndergradMod.html)
