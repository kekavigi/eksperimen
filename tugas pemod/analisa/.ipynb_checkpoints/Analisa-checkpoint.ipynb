# %% [markdown]
# # Memanggang Data

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Mentah

# %%
raw = pd.read_csv('out_sublane.csv', sep=';')
raw = raw.dropna()

# %% [markdown]
# Langkah pertama analisa dimulai dengan merapikan data. Pertama kita membuang baris data kendaraan yang mengandung `NaN`. Selanjutnya dengan membuang baris data yang letaknya tidak di jalan.  *Technically speaking*, kendaraan sebenarnya berada di `point_x`, dengan kata lain yakni tepat diujung jalan. Alasan saya ngebuang dua hal ini, karena bakal sulit untuk merapikan datanya :(

# %%
raw.tail()
# Out:
#         timestep_time  edge_id    lane_id   vehicle_id  vehicle_pos  \
# 883911         4999.0  jalan#3  jalan#3_1  fmobil2.669        13.51
# 883913         4999.0  jalan#4  jalan#4_1  fmobil2.668         6.24
# 883914         4999.0  jalan#5  jalan#5_0  fmotor.1291        36.21
# 883915         4999.0  jalan#5  jalan#5_1  fmobil2.667        63.46
# 883916         4999.0  jalan#5  jalan#5_1  fmotor.1289       111.00
#
#         vehicle_speed
# 883911          19.78
# 883913          24.24
# 883914          19.42
# 883915          19.51
# 883916          19.25

# %% [markdown]
# welp, terdapat 883K baris data. Coba kita lihat data untuk sebuah motor yang bergerak dari selatan ke utara, `-fmotor.2`

# %%
raw[raw.vehicle_id=='-fmotor.2']
# Out:
#       timestep_time   edge_id     lane_id vehicle_id  vehicle_pos  \
# 41              2.0  -jalan#5  -jalan#5_1  -fmotor.2        32.22
# 67              3.0  -jalan#5  -jalan#5_1  -fmotor.2        52.10
# 96              4.0  -jalan#5  -jalan#5_1  -fmotor.2        69.78
# 129             5.0  -jalan#5  -jalan#5_1  -fmotor.2        88.96
# 166             6.0  -jalan#5  -jalan#5_1  -fmotor.2       108.25
# 201             7.0  -jalan#4  -jalan#4_1  -fmotor.2         6.83
# 242             8.0  -jalan#3  -jalan#3_1  -fmotor.2        14.08
# 293             9.0  -jalan#3  -jalan#3_1  -fmotor.2        33.67
# 340            10.0  -jalan#2  -jalan#2_1  -fmotor.2         9.25
# 398            11.0  -jalan#2  -jalan#2_1  -fmotor.2        28.07
# 457            12.0  -jalan#2  -jalan#2_1  -fmotor.2        47.57
# 521            13.0  -jalan#2  -jalan#2_1  -fmotor.2        66.74
# 584            14.0  -jalan#2  -jalan#2_1  -fmotor.2        85.46
# 651            15.0  -jalan#2  -jalan#2_1  -fmotor.2       104.66
# 721            16.0  -jalan#2  -jalan#2_1  -fmotor.2       123.87
# 788            17.0  -jalan#2  -jalan#2_1  -fmotor.2       142.69
# 862            18.0  -jalan#2  -jalan#2_1  -fmotor.2       162.34
# 940            19.0  -jalan#2  -jalan#2_1  -fmotor.2       182.20
# 1017           20.0  -jalan#2  -jalan#2_1  -fmotor.2       200.68
# 1096           21.0  -jalan#2  -jalan#2_1  -fmotor.2       220.59
# 1178           22.0  -jalan#2  -jalan#2_1  -fmotor.2       240.12
# 1261           23.0  -jalan#2  -jalan#2_1  -fmotor.2       259.05
# 1348           24.0  -jalan#2  -jalan#2_1  -fmotor.2       277.91
# 1435           25.0  -jalan#2  -jalan#2_1  -fmotor.2       297.04
# 1522           26.0  -jalan#2  -jalan#2_1  -fmotor.2       316.88
# 1615           27.0  -jalan#2  -jalan#2_1  -fmotor.2       336.76
# 1712           28.0  -jalan#2  -jalan#2_1  -fmotor.2       355.21
# 1809           29.0  -jalan#2  -jalan#2_1  -fmotor.2       374.39
# 1908           30.0  -jalan#2  -jalan#2_1  -fmotor.2       393.67
# 1988           31.0  -jalan#1  -jalan#1_1  -fmotor.2         1.18
# 2085           32.0  -jalan#1  -jalan#1_1  -fmotor.2        20.51
# 2187           33.0  -jalan#1  -jalan#1_1  -fmotor.2        39.88
# 2292           34.0  -jalan#1  -jalan#1_1  -fmotor.2        58.25
# 2400           35.0  -jalan#1  -jalan#1_1  -fmotor.2        77.12
# 2508           36.0  -jalan#1  -jalan#1_1  -fmotor.2        95.86
# 2612           37.0  -jalan#1  -jalan#1_1  -fmotor.2       115.13
# 2720           38.0  -jalan#1  -jalan#1_1  -fmotor.2       134.92
# 2830           39.0  -jalan#1  -jalan#1_1  -fmotor.2       154.22
# 2941           40.0  -jalan#1  -jalan#1_1  -fmotor.2       173.25
# 3054           41.0  -jalan#1  -jalan#1_1  -fmotor.2       192.64
# 3168           42.0  -jalan#1  -jalan#1_1  -fmotor.2       212.24
# 3281           43.0  -jalan#1  -jalan#1_1  -fmotor.2       232.13
# 3394           44.0  -jalan#1  -jalan#1_1  -fmotor.2       251.70
# 3505           45.0  -jalan#1  -jalan#1_0  -fmotor.2       271.08
# 3618           46.0  -jalan#1  -jalan#1_0  -fmotor.2       290.32
# 3737           47.0  -jalan#1  -jalan#1_0  -fmotor.2       310.30
# 3857           48.0  -jalan#1  -jalan#1_0  -fmotor.2       329.39
# 3977           49.0  -jalan#1  -jalan#1_0  -fmotor.2       348.27
# 4100           50.0  -jalan#1  -jalan#1_0  -fmotor.2       363.15
# 4226           51.0  -jalan#1  -jalan#1_0  -fmotor.2       382.38
# 4350           52.0  -jalan#1  -jalan#1_0  -fmotor.2       391.61
#
#       vehicle_speed
# 41            20.00
# 67            19.88
# 96            17.68
# 129           19.18
# 166           19.29
# 201           19.35
# 242           19.20
# 293           19.59
# 340           19.22
# 398           18.82
# 457           19.50
# 521           19.18
# 584           18.71
# 651           19.20
# 721           19.21
# 788           18.81
# 862           19.65
# 940           19.86
# 1017          18.48
# 1096          19.91
# 1178          19.53
# 1261          18.93
# 1348          18.86
# 1435          19.13
# 1522          19.84
# 1615          19.88
# 1712          18.45
# 1809          19.18
# 1908          19.29
# 1988          19.63
# 2085          19.32
# 2187          19.37
# 2292          18.37
# 2400          18.88
# 2508          18.74
# 2612          19.27
# 2720          19.79
# 2830          19.31
# 2941          19.02
# 3054          19.39
# 3168          19.60
# 3281          19.88
# 3394          19.57
# 3505          19.38
# 3618          19.24
# 3737          19.99
# 3857          19.08
# 3977          18.89
# 4100          14.87
# 4226          19.23
# 4350           9.23

# %% [markdown]
# Terlihat bahwa `vehicle_pos` nilainya dihitung berdasarkan sejauh mana posisi kendaraan berada dari titik awal ruas jalan. Untuk mempermudah analisa, lebih baik jika `vehicle_pos` dihitung dari posisi kendaraan tersebut di-*spawn*.
#
# Berikut kita mencari panjang setiap ruas jalan. Perhatikan bahwa panjang `jalan#N` dan `-jalan#N` tidak sama, karena ruas jalan tidak lurus :/

# %%
for arah in ['', '-']:
    for edge in range(1, 6):
        edge_id = arah + 'jalan#' + str(edge)
        print(edge_id, max(raw[raw.edge_id==edge_id].vehicle_pos))
# Out:
# jalan#1 396.3
# jalan#2 421.13
# jalan#3 43.24
# jalan#4 10.0
# jalan#5 120.37
# -jalan#1 394.71
# -jalan#2 411.98
# -jalan#3 43.28
# -jalan#4 11.63
# -jalan#5 120.47

# %% [markdown]
# Selanjutnya, kita akan mencari jarak yang perlu ditambahkan ke setiap data. *i.e.*, `vehicle_pos` bernilai `36` dengan `edge_id` bernilai `jalan#3` akan perlu ditambah dengan `396.3 + 421.13`.

# %%
corrected_pos = {}

cumsum = [0]
for edge in range(1, 6):
    edge_id = 'jalan#' + str(edge)
    cumsum.append(round(cumsum[-1] + max(raw[raw.edge_id==edge_id].vehicle_pos), 3))
for edge in range(1, 6):
    edge_id = 'jalan#' + str(edge)
    corrected_pos[edge_id] = cumsum[edge-1]    

cumsum = [0]
for edge in reversed(range(1, 6)):
    edge_id = '-jalan#' + str(edge)
    cumsum.append(round(cumsum[-1] + max(raw[raw.edge_id==edge_id].vehicle_pos), 3))
for edge in reversed(range(1, 6)):
    edge_id = '-jalan#' + str(edge)
    corrected_pos[edge_id] = cumsum[5-edge]    

corrected_pos
# Out:
# {'-jalan#1': 587.36,
#  '-jalan#2': 175.38,
#  '-jalan#3': 132.1,
#  '-jalan#4': 120.47,
#  '-jalan#5': 0,
#  'jalan#1': 0,
#  'jalan#2': 396.3,
#  'jalan#3': 817.43,
#  'jalan#4': 860.67,
#  'jalan#5': 870.67}

# %% [markdown]
# ## Mengubah Data `vehicle_pos`

# %%
raw[raw.edge_id=="jalan#5"].head()
# Out:
#       timestep_time  edge_id    lane_id vehicle_id  vehicle_pos  vehicle_speed
# 1084           20.0  jalan#5  jalan#5_1  fmobil2.0        21.63          24.93
# 1165           21.0  jalan#5  jalan#5_1  fmobil2.0        46.46          24.83
# 1248           22.0  jalan#5  jalan#5_1  fmobil2.0        71.24          24.78
# 1333           23.0  jalan#5  jalan#5_1  fmobil2.0        96.24          25.00
# 1505           25.0  jalan#5  jalan#5_0  fmobil1.0         9.15          18.94

# %%
raw["vehicle_pos"] = raw["vehicle_pos"] + raw.edge_id.map(corrected_pos)

# %%
raw[raw.edge_id=="jalan#5"].head()
# Out:
#       timestep_time  edge_id    lane_id vehicle_id  vehicle_pos  vehicle_speed
# 1084           20.0  jalan#5  jalan#5_1  fmobil2.0       892.30          24.93
# 1165           21.0  jalan#5  jalan#5_1  fmobil2.0       917.13          24.83
# 1248           22.0  jalan#5  jalan#5_1  fmobil2.0       941.91          24.78
# 1333           23.0  jalan#5  jalan#5_1  fmobil2.0       966.91          25.00
# 1505           25.0  jalan#5  jalan#5_0  fmobil1.0       879.82          18.94

# %% [markdown]
# terlihat data `vehicle_pos` menjadi lebih manusiawi.

# %% [markdown]
# ## Visualisasi Data

# %% [markdown]
# Karena data `vehicle_pos` sudah tidak bergantung pada `edge_id` dan `lane_id`, kita dapat membuangnya. Sebagai tambahan, tidak ada salahnya mengatur posisi kolom dari data

# %%
data = raw[['vehicle_id', 'timestep_time', 'vehicle_pos', 'vehicle_speed']]
del raw

# %% [markdown]
# Mari kita berfokus pada data kendaraan `-fmotor2`

# %%
sampel = data[data.vehicle_id=='-fmotor.2']
sampel
# Out:
#      vehicle_id  timestep_time  vehicle_pos  vehicle_speed
# 41    -fmotor.2            2.0        32.22          20.00
# 67    -fmotor.2            3.0        52.10          19.88
# 96    -fmotor.2            4.0        69.78          17.68
# 129   -fmotor.2            5.0        88.96          19.18
# 166   -fmotor.2            6.0       108.25          19.29
# 201   -fmotor.2            7.0       127.30          19.35
# 242   -fmotor.2            8.0       146.18          19.20
# 293   -fmotor.2            9.0       165.77          19.59
# 340   -fmotor.2           10.0       184.63          19.22
# 398   -fmotor.2           11.0       203.45          18.82
# 457   -fmotor.2           12.0       222.95          19.50
# 521   -fmotor.2           13.0       242.12          19.18
# 584   -fmotor.2           14.0       260.84          18.71
# 651   -fmotor.2           15.0       280.04          19.20
# 721   -fmotor.2           16.0       299.25          19.21
# 788   -fmotor.2           17.0       318.07          18.81
# 862   -fmotor.2           18.0       337.72          19.65
# 940   -fmotor.2           19.0       357.58          19.86
# 1017  -fmotor.2           20.0       376.06          18.48
# 1096  -fmotor.2           21.0       395.97          19.91
# 1178  -fmotor.2           22.0       415.50          19.53
# 1261  -fmotor.2           23.0       434.43          18.93
# 1348  -fmotor.2           24.0       453.29          18.86
# 1435  -fmotor.2           25.0       472.42          19.13
# 1522  -fmotor.2           26.0       492.26          19.84
# 1615  -fmotor.2           27.0       512.14          19.88
# 1712  -fmotor.2           28.0       530.59          18.45
# 1809  -fmotor.2           29.0       549.77          19.18
# 1908  -fmotor.2           30.0       569.05          19.29
# 1988  -fmotor.2           31.0       588.54          19.63
# 2085  -fmotor.2           32.0       607.87          19.32
# 2187  -fmotor.2           33.0       627.24          19.37
# 2292  -fmotor.2           34.0       645.61          18.37
# 2400  -fmotor.2           35.0       664.48          18.88
# 2508  -fmotor.2           36.0       683.22          18.74
# 2612  -fmotor.2           37.0       702.49          19.27
# 2720  -fmotor.2           38.0       722.28          19.79
# 2830  -fmotor.2           39.0       741.58          19.31
# 2941  -fmotor.2           40.0       760.61          19.02
# 3054  -fmotor.2           41.0       780.00          19.39
# 3168  -fmotor.2           42.0       799.60          19.60
# 3281  -fmotor.2           43.0       819.49          19.88
# 3394  -fmotor.2           44.0       839.06          19.57
# 3505  -fmotor.2           45.0       858.44          19.38
# 3618  -fmotor.2           46.0       877.68          19.24
# 3737  -fmotor.2           47.0       897.66          19.99
# 3857  -fmotor.2           48.0       916.75          19.08
# 3977  -fmotor.2           49.0       935.63          18.89
# 4100  -fmotor.2           50.0       950.51          14.87
# 4226  -fmotor.2           51.0       969.74          19.23
# 4350  -fmotor.2           52.0       978.97           9.23

# %%
plt.figure(figsize=(20,5))
# plot posisi - speed
sns.lineplot(sampel.vehicle_pos, sampel.vehicle_speed)

# %%
plt.figure(figsize=(20,5))
#plot time - speed
sns.lineplot(sampel.timestep_time, sampel.vehicle_speed)

# %%
#plot time - speed
sns.lineplot(sampel.vehicle_pos, sampel.timestep_time)

# %%
sns.lineplot("vehicle_pos", "vehicle_speed", data=data, ci=None)

# %% [markdown]
# welp, ternyata keos juga. Sebagai pelengkap, coba kita ambil beberapa sampel kendaraan lain.

# %%
# Mobil ke-200
sampel = data[data.vehicle_id=='fmobil1.200']

plt.figure(figsize=(20,5))
sns.lineplot(sampel.vehicle_pos, sampel.vehicle_speed)

# %%
# Angkot ke-10
sampel = data[data.vehicle_id=='fangkot.10']

plt.figure(figsize=(20,5))
sns.lineplot(sampel.vehicle_pos, sampel.vehicle_speed)

# %% [markdown]
# ## Pertimbangan Bumbu

# %% [markdown]
# Dalam membuat model untuk mengkategorikan kondisi jalan raya dari data ini, ada beberapa hal yang perlu diperhatikan:
# - tidak semua kendaraan memiliki jumlah `timestep_time` yang sama, bahkan untuk jenis kendaraan yg sama.
# - semua kendaraan hampir pasti memiliki data `vehicle_pos` yang unik.
# - Ada dua arus lalu lintas berbeda dalam model ini, yakni arus yang bergerak dari utara ke selatan, dan sebaliknya.
# - Well, sepertinya data ini mencangkup kondisi jalan dalam lancar, padat namun lancar, dan macet.
