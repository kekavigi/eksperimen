# %% [markdown]
# # Scrapping Digital Library ITB

# %% [markdown]
# ## abstrak
# salah satu nama proker di divisi himpunan saya: "Lex Luthor's Database" (tebak siapa yang ngusulkan nama itu). Secara sederhana, *#tidakmendetail*, proker ini bertugas untuk mencatat segala hal* ke sebuah database. Salah satunya, topik TA anak matematika. Tapi, jika anda membaca ini ketika notebook ini ditulis, website [Digital Library ITB](www.digilib.itb.ac.id) did not spark fun. Hal ini disebabkan karena bagian "Pencarian Lanjut" (advanced search)-nya error terus. Tapi, fear not! masih ada cara untuk mendapatkan informasi TA anak matematika dari website sialan ini.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# regular expression
import re

# object serialization
import pickle
import numpy as np
import pandas as pd 

# proses request dan edit HTML
import urllib.request as U
from bs4 import BeautifulSoup as bs

# pretty print
from pprint import pprint

# menampilkan proses iterasi
from tqdm import tqdm

# %% [markdown]
# pertama, kita perlu fungsi untuk mengambil data dari halaman digilib

# %%
import re
import sys
import pickle
import urllib.request as U
from bs4 import BeautifulSoup as bs
from pprint import pprint
from tqdm import tqdm


URL = 'https://digilib.itb.ac.id/index.php/gdl/view/{}'

def dictify(num):
  res = {}

  try:
    with U.urlopen('https://digilib.itb.ac.id/index.php/gdl/view/' + str(num)) as f:
      raw = f.read().decode('utf8', 'ignore')
      soup = bs(raw, 'html.parser')

      tmp = []
      for p in soup.findAll('p')[1:]:
        # pakai try-except karna ada p tanpa class
        # cuma <p>
        try:
          if 'text-left' in p['class']:
            tmp2 = re.sub('(\n|\r|\t)', '', p.decode_contents())
            tmp2 = re.sub(' +', ' ', tmp2)
            tmp.append(tmp2.strip())
        except: pass
      res['judul'] = tmp[0]

      if len(tmp[1]) >= 3:
            res['abstrak'] = tmp[1]

      tmp = soup.findAll('blockquote')[0]

      for tr in tmp.findAll('tr'):
        cols = [x.decode_contents() for x in tr.findAll('td')]
        key = cols[0]
        val = re.sub('(<. [^>]*>|<\/.>)', '', cols[2])
        val = re.sub('(\n|\r|\t)', '', val)
        val = re.sub(' +', ' ', val)

        if val!='':
          if key=='Kontributor / Dosen Pembimbing' and len(val) >= 3:
              res['kontributor'] = val

          elif key=='Jenis Koleksi':                 res['jenis'] = val
          elif key=='Penerbit':                      res['penerbit'] = val
          elif key=='Fakultas':                      res['fakultas'] = val
          elif key=='Subjek':                        res['subjek'] = val
          elif key=='Kata Kunci':                    res['kunci'] = val
          elif key=='Tanggal Input':                 res['tanggal'] = val
  
  except: pass
  return res

# %% [markdown]
# lalu kita perlu fungsi untuk mengautomasi proses download. Karena program ini dijalankan di cloud, terdapat batasan waktu sekitar 2-3 jam sebelum proses ini dihentikan secara otomatis oleh sistem (dari sisi provider, tentunya mereka tidak ingin resource mereka terbuang karena satu *chunck* kode berjalan selama itu). Jadi, cara saya dengan mendownload 100 data lalu menyimpannya ke sebuah file pickle biar mudah digabungkan nantinya.

# %%
def batch_download(start, end, batch_size=100):
    for batch in range(start, end+1, batch_size):
        
        result = {}
        for num in tqdm(range(batch, batch+batch_size), desc=str(batch)):
            tmp = str(num)
            result[tmp] = dictify(tmp)

        with open('drive/My Drive/pickles/pickle_'+tmp, 'wb') as outfile:
            pickle.dump(result, outfile, -1)

# %%
#batch_download(33301, 33400)

# %% [markdown]
# selanjutnya kita tinggal menggabungkan data

# %%
result = {}
for n in tqdm(range(1, 420)):
  with open('drive/My Drive/pickles/pickle_{}00'.format(n), 'rb') as outfile:
    result.update(pickle.load(outfile))

data = pd.DataFrame.from_dict(result, orient='index')
# Out:
# 100%|██████████| 419/419 [00:00<00:00, 542.12it/s]

# %%
data.head()
# Out:
#                                                    judul  ... subjek
# 1      A Design and An Implementation of Parallel Bat...  ...    NaN
# 10                                     Hukum dan warfare  ...    NaN
# 100                         Murattal Quran: 110-An Nashr  ...    NaN
# 1000   STRUKTUR PASAR DAN PERFORMANSI INDUSTRI PERBAN...  ...    NaN
# 10000  FACTORS THAT INFLUENCES Y GREEN TEA CONSUMER P...  ...    NaN
#
# [5 rows x 10 columns]

# %% [markdown]
# karena kita perlu mengubah data ini ke bentuk csv, kita perlu cari separator yang cocok untuk data ini.

# %%
'$' in data.to_string()
# Out:
# False

# %% [markdown]
# karena data ternyata punya karakter non UTF-8, kita terpaksa ngebuang karakter-karakter tersebut

# %%
with open('drive/My Drive/digi.csv', 'w', encoding='utf8', errors='replace') as f:
    data.to_csv(f, sep='$')

# %% [markdown]
# ## Merapikan Data
#
# Setelah mendapatkan data mentah dari Digital Library, kita melihat banyak data yang berantakan. Karena saya berfokus untuk mencari data "S1-Tugas Akhir", saya mencoba mencari tahu informasi dari kolom `oleh`.

# %%
import pandas as pd
import numpy as np
import re

# %%
digi = pd.read_csv('digi.csv', sep='$')
digi.head()
# Out:
#    index                                              judul  \
# 0      1  A Design and An Implementation of Parallel Bat...
# 1     10                                  Hukum dan warfare
# 2    100                       Murattal Quran: 110-An Nashr
# 3   1000  STRUKTUR PASAR DAN PERFORMANSI INDUSTRI PERBAN...
# 4  10000  FACTORS THAT INFLUENCES Y GREEN TEA CONSUMER P...
#
#                                              abstrak  \
# 0                                                  A
# 1                                                  a
# 2                                    MP3 File Audio.
# 3                                                  S
# 4  Persaingan di antara produsen minuman teh hija...
#
#                                 oleh                              kontributor  \
# 0             Adang Suwandi, DR. IR.                                        A
# 1                 Onno W. Purbo, PhD                                        #
# 2                           Ghamiidi                digitized by Unit Salman.
# 3                    Rina Indiastuti                                        P
# 4  ARIA WIRA SAMUDERA (NIM 19005050)  Pembimbing : Drs. Herry Hudrasyah, M.A.
#
#               jenis              tanggal                             penerbit  \
# 0  Literatur Kelabu  2007-02-14 18:46:57                                  NaN
# 1  Literatur Kelabu  2007-02-14 18:46:56                                  NaN
# 2           Anggota  2004-09-15 16:24:44                                  NaN
# 3        S2 - Tesis  2017-09-27 14:50:29  FTI - Teknik dan Manajemen Industri
# 4    S1-Tugas Akhir  2009-07-03 16:07:42         Sekolah Bisnis dan Manajemen
#
#                              fakultas  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3   Fakultas Teknologi Industri (FTI)
# 4  Sekolah Bisnis dan Manajemen (SBM)
#
#                                             kunci subjek
# 0                                             NaN    NaN
# 1                                             NaN    NaN
# 2                       murattal quran, an nashr.    NaN
# 3                                             NaN    NaN
# 4  Preferensi, Fenomena, Konsumen, Faktor analisa    NaN

# %%
digi.oleh[:100]
# Out:
# 0                                Adang Suwandi, DR. IR.
# 1                                    Onno W. Purbo, PhD
# 2                                              Ghamiidi
# 3                                       Rina Indiastuti
# 4                     ARIA WIRA SAMUDERA (NIM 19005050)
# 5                ARIEF BARKAH KOESDWIADY (NIM 13304079)
# 6                       ARIEF MUCHANDOKO (NIM 28191039)
# 7                  ARIEF PERDANA PUTRA (NIM 152 04 052)
# 8                    ARIEF PLANTALUKMANA (NIM 13003082)
# 9                         ARIEF SUDIANTO (NIM 25406043)
# 10                     ARIEF TYAS ASMARA (NIM 28195045)
# 11    ARIE PURNOMO RUSLI (NIM 15004020) dan RIASTRI ...
# 12                          ARIF HAENDRA (NIM 23105001)
# 13                     ARIF RAHMAN HAKIM (NIM 13102048)
# 14                                               Rizwar
# 15                     ARIF RAHMAN HAKIM (NIM 13102121)
# 16                     ARIF RAHMAN HAKIM (NIM 13102121)
# 17                             ARIFUDDIN (NIM:22199012)
# 18                            ARI IRAWAN (NIM 25006026)
# 19                          ARIS ARYANTO (NIM 25006022)
# 20                           ARI SUZALIN (NIM 12204056)
# 21                                 ARIWI (NIM 20206033)
# 22              ARIYANA DWIPUTRA NUGRAHA (NIM 13703020)
# 23                    ARIZAL AKBAR ZIKRI (NIM 13604052)
# 24                                        Rustam Raswil
# 25                     A. RIZAL MOHAMMAD (NIM 10203020)
# 26                         ARIZKA DIKSON (NIM 13504133)
# 27                       ARMEN ADEKRISTI (NIM 15003099)
# 28                               ARMETRA (NIM 13104065)
# 29                  ARNE ADRYANTA BANGUN (NIM 13202106)
#                             ...
# 70                AYATULLAH ARRUHUL AMIN (NIM 10103061)
# 71                         AYI FAJARWATI (NIM 15304048)
# 72                        AYU FITRA SARI (NIM 10104077)
# 73                           AYUNINGTYAS (NIM 10105066)
# 74                AZHARRUDIN BIN ASROKIN (NIM 23604709)
# 75                          AZISA NOOR (NIM 152 04 021)
# 76                  AZIZA ADDINA PERMATA (NIM 13004107)
# 77                   BAGUS BHIRAWA PUTRA (NIM 23105013)
# 78                         Tien Sukartini Parmas Sukria
# 79                         BAGUS HARYADI (NIM 23805003)
# 80                         BAGUS PANDEGA (NIM 17003022)
# 81                       BAGUS WICAKSONO (NIM 19005058)
# 82                        BAIHAQIE HUSNI (NIM 15201007)
# 83                BAMBANG BUDI PAMUNGKAS (NIM 13303055)
# 84                     BAMBANG ISMAIL T. (NIM 13102059)
# 85                     BAMBANG PRIANDOKO (NIM 33302001)
# 86                    BAMBANG WIBIYANTO (NIM S2-818305)
# 87                      BASKARA ADHITAMA (NIM 10104019)
# 88                          BASKORO TEJO (NIM 13104017)
# 89                              Yohanes Inigo Wicaksono
# 90                     BAYU ANDI NUGROHO (NIM 15104037)
# 91                   BAYU DWI RAHMATYO (NIM 152 04 060)
# 92                   BAYU GENIA KRISHBIE (NIM 17204021)
# 93                          BAYU LAKSONO (NIM 13103098)
# 94                          BAYU PRABOWO (NIM 13703031)
# 95                 BAYU PRAMUDITA KRISNA (NIM 13003055)
# 96                    BAYU PRATAMA PURBA (NIM 13103022)
# 97                         BAYU WARIANTO (NIM 95006027)
# 98                          BEDY PURNAMA (NIM 23206330)
# 99                     BELINDA FEBRIANIE (NIM 10104028)
# Name: oleh, Length: 100, dtype: object

# %% [markdown]
# Terlihat sebagian data di kolom ini mengandung informasi NIM. Pengamatan lebih lanjut, banyak pul data yang meletakkan data `kontributor` di sini. Ada kasus dimana sebuah buku dicetak oleh dua orang atau lebih. Saya memilih untuk memikirkan hal ini nanti saja, dan memutuskan untuk memisahkan data orang pertama dengan data NIM mereka.

# %%
pd.options.mode.chained_assignment = None

digi['nim'] = 0

for idx in digi.index:
    text = digi['oleh'][idx]
    
    if type(text)==str:    
        if '(' in text:
            nama, b = text.split('(', 1)
            nim = re.sub('\D', '', b)[:8]
        elif '[' in text:
            nama, b = text.split('[', 1)
            nim = re.sub('\D', '', b)[:8]
        else: continue

        if nim=='': nim=0;
        digi['oleh'][idx] = nama.title()
        digi['nim'][idx]  = int(nim)

# %%
digi
# Out:
#        index                                              judul  \
# 0          1  A Design and An Implementation of Parallel Bat...
# 1         10                                  Hukum dan warfare
# 2        100                       Murattal Quran: 110-An Nashr
# 3       1000  STRUKTUR PASAR DAN PERFORMANSI INDUSTRI PERBAN...
# 4      10000  FACTORS THAT INFLUENCES Y GREEN TEA CONSUMER P...
# 5      10001  PEMBUATAN PERANGKAT AKUISISI DATA TOMOGRAFI EL...
# 6      10002  MANAJEMEN PERUBAHAN SUMBER DAYA MANUSIA UNTUK ...
# 7      10003                        RUMAH SAKIT KANKER SURABAYA
# 8      10004    MEMBRAN KRISTALISATOR UNTUK PENGOLAHAN AIR LAUT
# 9      10005  THE ROLE OF MARKET FORCES AND SPATIAL PLANNING...
# 10     10006  PERENCANAAN ORGANISASI, SISTEM &amp; PROSEDUR ...
# 11     10007  KAJIAN FORMAT KONTRAK PADA PROYEK KONSTRUKSI P...
# 12     10008  ANALISIS KEGAGALAN DAN PERHITUNGAN UMUR TEKNIS...
# 13     10009                    PERANCANGAN MODUL SPINDEL FREIS
# 14      1001  PENGARUH SALINITAS DAN TEMPERATUR TERHADAP KEL...
# 15     10010  PENGARUH PERLAKUAN PANAS PADA Al 204.0 TERHADA...
# 16     10011  PENGARUH PERLAKUAN PANAS PADA Al 204.0 TERHADA...
# 17     10012   PERILAKU PENGKASARAN STRUKTUR MIKRO PADUAN Pb-Sn
# 18     10013  KAJIAN PERILAKU STRUKTUR SILO BETON DENGAN MET...
# 19     10015  KINERJA PORTAL BETON BERTULANG DENGAN DINDING ...
# 20     10016  PENGEMBANGAN LAPANGAN X DENGAN TEKNIK RESERVOI...
# 21     10017  MODEL PEMBELAJARAN KOOPERATIF TIPE STAD DENGAN...
# 22     10018  SINTESIS dan KARAKTERISASI XEROGELS TiO2-SiO2-...
# 23     10019  PEMODELAN GERAK PESAWAT TERBANG MATRA LONGITUD...
# 24      1002  ISOLASI DAN IDENTIFIKASI FOSFOLIPID DALAM KARE...
# 25     10020  PERSAMAAN OPPENHEIMER-VOLKOFF MENGGUNAKAN SIST...
# 26     10021  PEMBANGUNAN APLIKASI ANALISIS PERGERAKAN NILAI...
# 27     10022  PEMBUATAN ALAT BANTU DESAIN KOMPONEN AKSIAL DA...
# 28     10023  PERANCANGAN SISTEM PIPA PENYALUR AIR BAKU KAPA...
# 29     10024  PERANCANGAN DAN SIMULASI DIODA AVALANS SILIKON...
# ...      ...                                                ...
# 44634  45046  Inverse design of discrete mechanical metamate...
# 44635  45047                  Development of semiconducting ScN
# 44636  45048  PRODUKSI KARBON AKTIF DARI TANDAN KOSONG KELAP...
# 44637  45049  AI COPERNICUS 'DISCOVERS' THAT EARTH ORBITS TH...
# 44638  45050  PRODUKSI HYDROCHAR BERKUALITAS TINGGI DARI RUM...
# 44639  45051  Kajian Minimalisasi Flare Kondisi Operasi Norm...
# 44640  45052  PENGEMBANGAN TEKNOLOGI PRODUKSI KALIUM KARBONA...
# 44641  45053  TRANSFORMASI TRANSIEN GEN ARTEMISINIC ALDEHYDE...
# 44642  45054  Machine learning in materials design and disco...
# 44643  45055  SINTESIS DAN KARAKTERISASI NANOPARTIKEL ZnO ME...
# 44644  45056  STUDI ESTERIFIKASI ROSIN DARI GETAH PINUS MERK...
# 44645  45057  ANALISIS PERBANDINGAN POWER SPECTRAL DENSITY P...
# 44646  45058  Relationship between learners’ motivation and ...
# 44647  45059  ISOLASI SENYAWA ANTIOKSIDAN DARI EKSTRAK DAUN ...
# 44648  45060  AKTIVITAS ANTIOKSIDAN EKSTRAK DAUN, KULIT BATA...
# 44649  45061  ISOLASI SENYAWA ANTIOKSIDAN DAUN JAMBU BOL (SY...
# 44650  45062  Pressure-Rate Convolution And Deconvolution Re...
# 44651  45063  ANTIBACTERIAL ACTIVITIES OF 15 GRADES OF BLACK...
# 44652  45064  Molecular Dynamics Simulation Of Methane Gas F...
# 44653  45065  Isolasi Senyawa Antioksidan dari Biji Pepaya (...
# 44654  45066  Empirical Analysis For The Characterization Of...
# 44655  45067  OPTIMASI KONDISI UNTUK EKSTRAKSI GINGEROL DARI...
# 44656  45068  PHYTOCHEMICAL AND ANTIOXIDANT STUDY OF MURRAYA...
# 44657  45069  PENGEMBANGAN KATALIS NiMo/?-Al2O3 PADA PROSES ...
# 44658  45070  SELF-MEDICATION WITH HERBAL PRODUCT AND SUPPLE...
# 44659  45071  PENGARUH PENGERINGAN TERHADAP JUMLAH ASAM KLOR...
# 44660  45072  ANALISIS LIFTING PADA STRUKTUR JACKET PLATFORM...
# 44661  45073  PERENCANAAN STRUKTUR DERMAGA PENUMPANG DI PELA...
# 44662  45074  PERENCANAAN STRUKTUR DERMAGA PELABUHAN BATUBAR...
# 44663  45075  INTERPRETASI DATA “CONTROLLED SOURCE AUDIO MAG...
#
#                                                  abstrak  \
# 0                                                      A
# 1                                                      a
# 2                                        MP3 File Audio.
# 3                                                      S
# 4      Persaingan di antara produsen minuman teh hija...
# 5      Tomografi Elektrik adalah metoda pencitraan di...
# 6      Suatu perusahaan merupakan sistem terbuka yang...
# 7      Perancangan Tugas Akhir ini mengambil kasus pr...
# 8      Membran kristalisator (MCr) merupakan teknik b...
# 9      This study is about the role of market forces ...
# 10     Pertumbuhan ekonomi Indonesia yang cukup tingg...
# 11     Proyek konstruksi merupakan suatu rangkaian ke...
# 12     Setelah beroperasi selama 16 tahun, dua belas ...
# 13     Modul spindel terdiri dari poros spindel beser...
# 14     ABSTRAK:Suatu penelitian mengenai pengaruh sal...
# 15     Al 204.0 merupakan casting aluminum dengan uns...
# 16     Al 204.0 merupakan casting aluminum dengan uns...
# 17     Abstrak: Pb-Sn merupakan paduan yang digunakan...
# 18     Kajian pada thesis ini didasari oleh banyaknya...
# 19     Sudah menjadi ketentuan umum bahwa semakin ber...
# 20     Lapangan X merupakan gabungan dari struktur fo...
# 21     Pelajaran fisika merupakan pelajaran yang sang...
# 22     Metode Sol Gel telah menjadi perhatian ilmu pe...
# 23     MATLAB/Simulink merupakan produk yang dikeluar...
# 24                                                     H
# 25     Persamaan Oppenheimer-Volkoff merupakan persam...
# 26     Dalam perdagangan saham terdapat banyak pendek...
# 27     Pemakaian profil baja sebagai elemen struktur ...
# 28     Kawasan industri di daerah pantai Jakarta Utar...
# 29     Gejala transien seperti petir dapat terjadi se...
# ...                                                  ...
# 44634  Mechanical and phononic metamaterials exhibiti...
# 44635  Since the 1960s advances in electronic and opt...
# 44636  PRODUKSI KARBON AKTIF DARI TANDAN KOSONG KELAP...
# 44637  Astronomers took centuries to figure it out. B...
# 44638  PRODUKSI HYDROCHAR BERKUALITAS TINGGI DARI RUM...
# 44639  Kajian Minimalisasi Flare Kondisi Operasi Norm...
# 44640  PENGEMBANGAN TEKNOLOGI PRODUKSI KALIUM KARBONA...
# 44641  Peningkatkan kebutuhan artemisinin secara glob...
# 44642  We provide a brief discussion of “What ismachi...
# 44643  SINTESIS DAN KARAKTERISASI NANOPARTIKEL ZnOMEN...
# 44644  STUDI ESTERIFIKASI DAN MODIFIKASI ROSINDARI GE...
# 44645  Elektroda EEG dibedakan menjadi dua jenis yait...
# 44646  In this work we study how different motivation...
# 44647  Antioksidan adalah senyawa yang mampu menghamb...
# 44648  Radikal bebas merupakan senyawa kimia dengan s...
# 44649  Senyawa radikal bebas merupakan senyawa yang m...
# 44650  This paper introduces new approach for pressur...
# 44651  Camellia sinensis dikenal sebagai teh. Teh mem...
# 44652  The transport properties of fluids in nanopore...
# 44653  Antioksidan adalah zat yang memiliki kemampuan...
# 44654  Among the several activities involved in oil e...
# 44655  Determinasi tumbuhan dilakukan di Herbarium Ba...
# 44656  Daun Murraya koenigii ( daun kari) merupakan s...
# 44657  PENGEMBANGAN KATALIS NiMo/?-Al2O3 PADA PROSES ...
# 44658  Pengobatan mandiri dapat didefinisikan sebagai...
# 44659  Determinasi tumbuhan dilakukan di Herbarium Ba...
# 44660  Anjungan lepas pantai tipe jacket platform ada...
# 44661  Prediksi akan meningkatnya arus transportasi p...
# 44662  Pembangunan Pelabuhan batubara pada Desa Bunat...
# 44663  CSAMT adalah salah satu metode elektromagnetik...
#
#                                   oleh  \
# 0               Adang Suwandi, DR. IR.
# 1                   Onno W. Purbo, PhD
# 2                             Ghamiidi
# 3                      Rina Indiastuti
# 4                  Aria Wira Samudera
# 5             Arief Barkah Koesdwiady
# 6                    Arief Muchandoko
# 44647  2019-11-21 09:10:39              SF - Sains dan Teknologi Farmasi
# 44648  2019-11-21 09:13:06              SF - Sains dan Teknologi Farmasi
# 44649  2019-11-21 09:17:43              SF - Sains dan Teknologi Farmasi
# 44650  2019-11-21 09:28:43                                     Lain-lain
# 44651  2019-11-21 09:39:47              SF - Sains dan Teknologi Farmasi
# 44652  2019-11-21 09:44:43                                     Lain-lain
# 44653  2019-11-21 09:50:46              SF - Sains dan Teknologi Farmasi
# 44654  2019-11-21 09:51:25                                     Lain-lain
# 44655  2019-11-21 10:04:40              SF - Sains dan Teknologi Farmasi
# 44656  2019-11-21 10:40:28              SF - Sains dan Teknologi Farmasi
# 44657  2019-11-21 11:04:03                            FTI - Teknik Kimia
# 44658  2019-11-21 11:04:32              SF - Sains dan Teknologi Farmasi
# 44659  2019-11-21 11:17:02              SF - Sains dan Teknologi Farmasi
# 44660  2019-11-21 11:28:15                               Teknik Kelautan
# 44661  2019-11-21 11:33:38                               Teknik Kelautan
# 44662  2019-11-21 11:47:49                               Teknik Kelautan
# 44663  2019-11-21 13:46:07                                FMIPA - Fisika
#
#                                                 fakultas  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                      Fakultas Teknologi Industri (FTI)
# 4                     Sekolah Bisnis dan Manajemen (SBM)
# 5                                                    NaN
# 6                     Sekolah Bisnis dan Manajemen (SBM)
# 7                                                    NaN
# 8                                                    NaN
# 9      Sekolah Arsitektur, Perencanaan dan Pengembang...
# 10                    Sekolah Bisnis dan Manajemen (SBM)
# 11                                                   NaN
# 12           Fakultas Teknik Mesin dan Dirgantara (FTMD)
# 13                                                   NaN
# 14              Sekolah Ilmu dan Teknologi Hayati (SITH)
# 15           Fakultas Teknik Mesin dan Dirgantara (FTMD)
# 16                                                   NaN
# 17     Fakultas Teknik Pertambangan dan Perminyakan (...
# 18           Fakultas Teknik Sipil dan Lingkungan (FTSL)
# 19           Fakultas Teknik Sipil dan Lingkungan (FTSL)
# 20                                                   NaN
# 21                                                   NaN
# 22           Fakultas Teknik Mesin dan Dirgantara (FTMD)
# 23                                                   NaN
# 24     Fakultas Matematika dan Ilmu Pengetahuan Alam ...
# 25                                                   NaN
# 26         Sekolah Teknik Elektro dan Informatika (STEI)
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 44634  Fakultas Matematika dan Ilmu Pengetahuan Alam ...
# 44635  Fakultas Matematika dan Ilmu Pengetahuan Alam ...
# 44636                  Fakultas Teknologi Industri (FTI)
# 44637  Fakultas Matematika dan Ilmu Pengetahuan Alam ...
# 44638                  Fakultas Teknologi Industri (FTI)
# 44639                  Fakultas Teknologi Industri (FTI)
# 44640                  Fakultas Teknologi Industri (FTI)
# 44641                               Sekolah Farmasi (SF)
# 44642  Fakultas Matematika dan Ilmu Pengetahuan Alam ...
# 44643                  Fakultas Teknologi Industri (FTI)
# 44644                  Fakultas Teknologi Industri (FTI)
# 44645  Fakultas Matematika dan Ilmu Pengetahuan Alam ...
# 44646  Fakultas Matematika dan Ilmu Pengetahuan Alam ...
# 44647                               Sekolah Farmasi (SF)
# 44648                               Sekolah Farmasi (SF)
# 44649                               Sekolah Farmasi (SF)
# 44650                                                NaN
# 44651                               Sekolah Farmasi (SF)
# 44652                                                NaN
# 44653                               Sekolah Farmasi (SF)
# 44654                                                NaN
# 44655                               Sekolah Farmasi (SF)
# 44656                               Sekolah Farmasi (SF)
# 44657                  Fakultas Teknologi Industri (FTI)
# 44658                               Sekolah Farmasi (SF)
# 44659                               Sekolah Farmasi (SF)
# 44660        Fakultas Teknik Sipil dan Lingkungan (FTSL)
# 44661        Fakultas Teknik Sipil dan Lingkungan (FTSL)
# 44662        Fakultas Teknik Sipil dan Lingkungan (FTSL)
# 44663  Fakultas Matematika dan Ilmu Pengetahuan Alam ...
#
#                                                    kunci  \
# 0                                                    NaN
# 1                                                    NaN
# 2                              murattal quran, an nashr.
# 3                                                    NaN
# 4         Preferensi, Fenomena, Konsumen, Faktor analisa
# 5      Tomografi elektrik 3-D, Distribusi resistivita...
# 6                SDM, PN Padalarang, manajemen perubahan
# 7               rumah sakit, kanker, radiologi, Surabaya
# 8      Membran kristalisator, Distilasi, Reverse osmo...
# 9      market forces, spatial planning, land developm...
# 10     project management, established target,organiz...
# 11     proyek konstruksi, pasca bencana, infrastruktu...
# 12     Boiler failure, CFD, Boiling induced errosion,...
# 13     Spindle Module, bearing preload, static and dy...
# 14     <br/><i>salinity, temperature, survival, growt...
# 15                     Al 204.0, Perlakuan panas, Korosi
# 16     Perlakuan panas, Al 204.0, Sifat mekanik, Laju...
# 17     Pb-Sn ; electrical industry ; machinery indust...
# 18     silo beton, dinding silo, hopper, metode eleme...
# 19     Material Dinding Pengisi, Material Ringan, Por...
# 20     lapangan, decline curve analysis (DCA), teknik...
# 21     Model Pembelajaran Kooperatif tipe STAD, Pende...
# 22     Sol Gel, Hybrid Organic Inorganic Materials, X...
# 23     MATLAB/Simulink, UAV HSFTB, analisis kestabila...
# 24                                                   NaN
# 25       persamaan Oppenheimer-Volkoff, sistem gas fermi
# 26     Saham, Analisis teknikal, Indikator teknikal, ...
# 27     bangunan teknik, profil baja, LRFD, grafik tah...
# 28     pipa air baku, pipa tanam, analisis crossing, ...
# 29        Dioda Avalans, Peredaman, Guard Ring, Simulasi
# ...                                                  ...
# 44634                                                  -
# 44635                                                  -
# 44636  biomassa, karbon aktif, hidrotermal, superkapa...
# 44637                                         TATA SURYA
# 44638                      biomassa, rumput laut, karbon
# 44639   flare, minimalisasi flare, gas, pengurangan g...
# 44640  cangkang sawit, ekstraksi, kalium karbonat, se...
# 44641  A. annua L., Konstruksi, pCAMBIA-dbr2, Transie...
# 44642                                                  -
# 44643    nanopartikel ZnO, antimikroba, Averrhoa bilimbi
# 44644   esterifikasi, gliserol, angka asam, warna, FT-IR
# 44645  Emotiv EPOC dan Insight, Impedansi, Stimulus A...
# 44646                                                  -
# 44647   antioksidan, daun pepaya, DPPH, aglikon flavonol
# 44648  antioksidan, DPPH, fosfomolibdenum, jeruk bali...
# 44649                                                  -
# 44650  Convolution and convolution technique, Rate tr...
# 44651                                                  -
# 44652  Molecular dynamics, Shale gas, Transport prope...
# 44653    Antioksidan, DPPH, biji papaya, alkaloid, fenol
# 44654  Elastic strength, Hydraulic fracturing, Compet...
# 44655  Gingerol, TLC scanner 3, Zingiber officinale R...
# 44656                                                  -
# 44657  Kata kunci: hidrodemetalisasi, katalis, logam,...
# 44658                                                  -
# 44659  asam klorogenat, TLC scanner 3, fenolik, Coffe...
# 44660  jacket platform, lifting, operasi, instalasi, ...
# 44661  perancangan struktur, deck on pile, dermaga, p...
# 44662                         batubara, dermaga, SAP2000
# 44663                  Metode CSAMT, Resistivitas, Suhu.
#
#                                     subjek       nim
# 0                                      NaN         0
# 1                                      NaN         0
# 2                                      NaN         0
# 3                                      NaN         0
# 4                                      NaN  19005050
# 5                                      NaN  13304079
# 6                                      NaN  28191039
# 7                                      NaN  15204052
# 8                                      NaN  13003082
# 9                                      NaN  25406043
# 10                                     NaN  28195045
# 11                                     NaN  15004020
# 12                                     NaN  23105001
# 13                                     NaN  13102048
# 14                                     NaN         0
# 15                                     NaN  13102121
# 16                                     NaN  13102121
# 17                                     NaN  22199012
# 18                                     NaN  25006026
# 19                                     NaN  25006022
# 20                                     NaN  12204056
# 21                                     NaN  20206033
# 22                                     NaN  13703020
# 23                                     NaN  13604052
# 24                                     NaN         0
# 25                                     NaN  10203020
# 26                                     NaN  13504133
# 27                                     NaN  15003099
# 28                                     NaN  13104065
# 29                                     NaN  13202106
# ...                                    ...       ...
# 44634                                  NaN         0
# 44635                                  NaN         0
# 44636                 Chemical engineering  23017030
# 44637                                  NaN         0
# 44638                 Chemical engineering  23017022
# 44639                 Chemical engineering  23015011
# 44640                                  NaN  23018015
# 44641                                  NaN  10712065
# 44642                                  NaN         0
# 44643                 Chemical engineering  23017031
# 44644                 Chemical engineering  23016051
# 44645                              Physics  20217313
# 44646                                  NaN         0
# 44647                                  NaN  10712067
# 44648                                  NaN  10712084
# 44649                                  NaN  10712094
# 44650                Hydraulic engineering         0
# 44651                                  NaN  10712701
# 44652  Industrial oils, fats, waxes, gases         0
# 44653                                  NaN  10712702
# 44654  Industrial oils, fats, waxes, gases         0
# 44655                                  NaN  10713765
# 44656                                  NaN  10713766
# 44657                 Chemical engineering  23017041
# 44658                                  NaN  10713767
# 44659                                  NaN  10713768
# 44660  Engineering &amp; allied operations  15508001
# 44661  Engineering &amp; allied operations  15508002
# 44662  Engineering &amp; allied operations  15508026
# 44663                              Physics  20214019
#
# [44664 rows x 12 columns]

# %%
digi.to_csv('digi_corrected.csv', sep='$', index=False)

# %% [markdown]
# ## Mencari Data TA Anak Matematika

# %%
digi = pd.read_csv('digi_corrected.csv', sep='$')
digi.head()
# Out:
#    index                                              judul  \
# 0      1  A Design and An Implementation of Parallel Bat...
# 1     10                                  Hukum dan warfare
# 2    100                       Murattal Quran: 110-An Nashr
# 3   1000  STRUKTUR PASAR DAN PERFORMANSI INDUSTRI PERBAN...
# 4  10000  FACTORS THAT INFLUENCES Y GREEN TEA CONSUMER P...
#
#                                              abstrak                    oleh  \
# 0                                                  A  Adang Suwandi, DR. IR.
# 1                                                  a      Onno W. Purbo, PhD
# 2                                    MP3 File Audio.                Ghamiidi
# 3                                                  S         Rina Indiastuti
# 4  Persaingan di antara produsen minuman teh hija...     Aria Wira Samudera
#
#                                kontributor             jenis  \
# 0                                        A  Literatur Kelabu
# 1                                        #  Literatur Kelabu
# 2                digitized by Unit Salman.           Anggota
# 3                                        P        S2 - Tesis
# 4  Pembimbing : Drs. Herry Hudrasyah, M.A.    S1-Tugas Akhir
#
#                tanggal                             penerbit  \
# 0  2007-02-14 18:46:57                                  NaN
# 1  2007-02-14 18:46:56                                  NaN
# 2  2004-09-15 16:24:44                                  NaN
# 3  2017-09-27 14:50:29  FTI - Teknik dan Manajemen Industri
# 4  2009-07-03 16:07:42         Sekolah Bisnis dan Manajemen
#
#                              fakultas  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3   Fakultas Teknologi Industri (FTI)
# 4  Sekolah Bisnis dan Manajemen (SBM)
#
#                                             kunci subjek       nim
# 0                                             NaN    NaN         0
# 1                                             NaN    NaN         0
# 2                       murattal quran, an nashr.    NaN         0
# 3                                             NaN    NaN         0
# 4  Preferensi, Fenomena, Konsumen, Faktor analisa    NaN  19005050

# %%
data = []
for idx in digi.index:
    if str(digi['nim'][idx])[:3]=='101': data.append(idx)

maths1 = digi.iloc[data].fillna('')
maths1.head()
# Out:
#     index                                              judul  \
# 47  10040  MODEL PENYEBARAN PENYAKIT AFRICAN HORSE SICKNE...
# 54  10048  PEMBUATAN PORTFOLIO OPTIMAL YANG ROBUST DENGAN...
# 70  10062  PENGGUNAAN SKEMA BAGI RAHASIA UNTUK MELAKUKAN ...
# 72  10064  EFISIENSI PENDESAKAN MINYAK PADA LOW-TENSION F...
# 73  10065  PELABELAN TOTAL LINGKARAN AJAIB SUPER PADA GRA...
#
#                                               abstrak  \
# 47  Tugas akhir ini membahas masalah model penyeba...
# 54  Pembuatan portfolio dalam keuangan dengan meng...
# 70  Skema bagi rahasia merupakan salah satu metode...
# 72  Low-Tension Flood merupakan salah satu metode ...
# 73  Pada tugas akhir ini, dibuktikan bahwa suatu g...
#
#                        oleh  \
# 47        Asnaini Maulidia
# 54      Astrid Ayuningtyas
# 70  Ayatullah Arruhul Amin
# 72          Ayu Fitra Sari
# 73             Ayuningtyas
#
#                                           kontributor           jenis  \
# 47                     Pembimbing: Dr. Nuning Nuraini  S1-Tugas Akhir
# 54  Pembimbing: Dr. Roberd Saragih dan Dr. Jalina ...  S1-Tugas Akhir
# 70          Pembimbing: Dr. Rinovia M. G. Simanjuntak  S1-Tugas Akhir
# 72  Pembimbing: Prof.Dr. Edy Soewono dan Prof.Dr.I...  S1-Tugas Akhir
# 73                      Pembimbing: Dr. M. Salman A.N  S1-Tugas Akhir
#
#                 tanggal penerbit fakultas  \
# 47  2017-09-27 11:43:07
# 54  2017-09-27 11:43:06
# 70  2017-09-27 11:43:05
# 72  2017-09-27 11:43:06
# 73  2017-09-27 11:43:08
#
#                                                 kunci subjek       nim
# 47  basic reproduction number, titik kesetimbangan...         10103037
# 54  Mean-Variansi Markowitz, Outlier, Jarak Mahala...         10104055
# 70          polinom, skema bagi rahasia, field, query         10103061
# 72  Low-Tension Flood, Injeksi Surfactant, persama...         10104077
# 73  pelabelan total ajaib super, Cn - cactus, graf...         10105066

# %%
maths1.to_csv('mathS1.csv', sep='$', index=False)
